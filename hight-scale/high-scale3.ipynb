# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.023603291468168086
# Classification error on testing sets using all features: 0.040909090909090895
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 15.0 out of 100
# corresponding indices: [3, 19, 28, 31, 47, 57, 66, 67, 77, 80, 103, 104, 153, 160, 162]
# classification error on train sets: 0.020788220008661762
# classification error on test sets: 0.04343434343434338
# solution 1:
# number of selected features is: 9.0 out of 100
# corresponding indices: [3, 19, 31, 47, 66, 103, 104, 153, 160]
# classification error on train sets: 0.03616284105673451
# classification error on test sets: 0.05757575757575761
# solution 2:
# number of selected features is: 8.0 out of 100
# corresponding indices: [3, 19, 31, 47, 103, 104, 153, 160]
# classification error on train sets: 0.04287570376786487
# classification error on test sets: 0.061111111111111116
# solution 3:
# number of selected features is: 12.0 out of 100
# corresponding indices: [3, 19, 31, 47, 66, 80, 103, 104, 118, 153, 160, 162]
# classification error on train sets: 0.024902555218709432
# classification error on test sets: 0.04747474747474745
# solution 4:
# number of selected features is: 9.0 out of 100
# corresponding indices: [3, 19, 31, 47, 103, 104, 153, 160, 162]
# classification error on train sets: 0.03616284105673451
# classification error on test sets: 0.05959595959595965
# solution 5:
# number of selected features is: 10.0 out of 100
# corresponding indices: [3, 19, 31, 47, 66, 103, 104, 118, 153, 160]
# classification error on train sets: 0.03053269813772197
# classification error on test sets: 0.05101010101010106
# solution 6:
# number of selected features is: 17.0 out of 100
# corresponding indices: [3, 19, 28, 31, 47, 57, 66, 67, 77, 80, 103, 104, 116, 135, 153, 160, 162]
# classification error on train sets: 0.018839324382849743
# classification error on test sets: 0.03838383838383841
# solution 7:
# number of selected features is: 20.0 out of 100
# corresponding indices: [3, 19, 28, 31, 47, 54, 57, 65, 66, 67, 77, 80, 86, 103, 104, 116, 126, 153, 160, 162]
# classification error on train sets: 0.01818969250757907
# classification error on test sets: 0.03737373737373739
# solution 8:
# number of selected features is: 11.0 out of 100
# corresponding indices: [3, 19, 31, 47, 80, 103, 104, 118, 153, 160, 162]
# classification error on train sets: 0.027717626678215646
# classification error on test sets: 0.0505050505050505
# solution 9:
# number of selected features is: 16.0 out of 100
# corresponding indices: [3, 19, 30, 31, 47, 48, 66, 67, 77, 80, 103, 104, 118, 153, 160, 162]
# classification error on train sets: 0.019705500216543936
# classification error on test sets: 0.03838383838383841
# solution 10:
# number of selected features is: 23.0 out of 100
# corresponding indices: [3, 4, 19, 28, 31, 36, 47, 50, 65, 66, 67, 80, 83, 86, 94, 98, 104, 126, 128, 135, 138, 153, 160]
# classification error on train sets: 0.015591165006496266
# classification error on test sets: 0.033333333333333326
# solution 11:
# number of selected features is: 19.0 out of 100
# corresponding indices: [3, 19, 28, 30, 31, 47, 57, 66, 67, 77, 80, 86, 103, 104, 105, 126, 153, 160, 162]
# classification error on train sets: 0.01840623646600259
# classification error on test sets: 0.036363636363636376
# solution 12:
# number of selected features is: 14.0 out of 100
# corresponding indices: [3, 19, 31, 47, 66, 67, 80, 98, 103, 104, 118, 153, 160, 162]
# classification error on train sets: 0.021221307925508914
# classification error on test sets: 0.04191919191919191
# solution 13:
# number of selected features is: 13.0 out of 100
# corresponding indices: [3, 19, 31, 47, 66, 67, 80, 98, 103, 104, 118, 153, 160]
# classification error on train sets: 0.023170203551320934
# classification error on test sets: 0.04191919191919191
# solution 14:
# number of selected features is: 35.0 out of 100
# corresponding indices: [3, 4, 5, 19, 24, 28, 30, 31, 36, 41, 42, 47, 50, 65, 66, 67, 77, 80, 83, 86, 94, 97, 104, 106, 110, 112, 117, 126, 135, 138, 144, 151, 153, 157, 160]
# classification error on train sets: 0.00822867042009523
# classification error on test sets: 0.03181818181818186
# solution 15:
# number of selected features is: 22.0 out of 100
# corresponding indices: [3, 4, 18, 19, 28, 31, 35, 47, 54, 57, 65, 66, 67, 77, 80, 100, 103, 104, 112, 116, 153, 160]
# classification error on train sets: 0.01624079688176705
# classification error on test sets: 0.03131313131313129
# solution 16:
# number of selected features is: 12.0 out of 100
# corresponding indices: [3, 19, 31, 47, 66, 80, 98, 103, 104, 118, 153, 160]
# classification error on train sets: 0.024902555218709432
# classification error on test sets: 0.042424242424242475
# solution 17:
# number of selected features is: 15.0 out of 100
# corresponding indices: [3, 19, 30, 31, 47, 48, 66, 67, 80, 98, 103, 104, 118, 153, 160]
# classification error on train sets: 0.020788220008661762
# classification error on test sets: 0.03838383838383841
# solution 18:
# number of selected features is: 24.0 out of 100
# corresponding indices: [3, 4, 19, 28, 31, 35, 47, 54, 57, 65, 66, 67, 80, 98, 103, 104, 112, 126, 128, 135, 138, 153, 160, 162]
# classification error on train sets: 0.013858813339107878
# classification error on test sets: 0.03282828282828287
# solution 19:
# number of selected features is: 21.0 out of 100
# corresponding indices: [3, 19, 28, 31, 35, 47, 54, 65, 66, 67, 80, 86, 98, 103, 104, 112, 126, 135, 153, 160, 162]
# classification error on train sets: 0.016890428757037723
# classification error on test sets: 0.03737373737373739
# solution 20:
# number of selected features is: 29.0 out of 100
# corresponding indices: [3, 4, 19, 24, 28, 30, 31, 36, 47, 50, 65, 66, 67, 77, 80, 86, 94, 97, 104, 106, 112, 117, 126, 135, 138, 151, 153, 157, 160]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.02929292929292926
# solution 21:
# number of selected features is: 15.0 out of 100
# corresponding indices: [3, 19, 30, 31, 47, 48, 66, 67, 80, 103, 104, 118, 153, 160, 162]
# classification error on train sets: 0.020788220008661762
# classification error on test sets: 0.04040404040404044
# solution 22:
# number of selected features is: 27.0 out of 100
# corresponding indices: [3, 4, 5, 19, 24, 28, 30, 31, 47, 65, 66, 67, 77, 80, 83, 86, 94, 97, 104, 106, 117, 126, 138, 153, 157, 160, 162]
# classification error on train sets: 0.011260285838025075
# classification error on test sets: 0.030303030303030276
# solution 23:
# number of selected features is: 30.0 out of 100
# corresponding indices: [3, 4, 5, 19, 24, 28, 30, 31, 36, 41, 47, 50, 65, 66, 67, 77, 80, 83, 86, 97, 104, 106, 117, 126, 138, 144, 151, 153, 157, 160]
# classification error on train sets: 0.009094846253789535
# classification error on test sets: 0.02777777777777779
# solution 24:
# number of selected features is: 34.0 out of 100
# corresponding indices: [3, 4, 19, 24, 28, 30, 31, 36, 41, 42, 47, 50, 65, 66, 67, 80, 83, 86, 94, 97, 98, 104, 106, 110, 116, 117, 126, 135, 138, 151, 153, 157, 160, 165]
# classification error on train sets: 0.008878302295366014
# classification error on test sets: 0.02777777777777779
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [3, 4, 5, 19, 24, 28, 30, 31, 36, 41, 47, 50, 65, 66, 67, 77, 80, 83, 86, 97, 104, 106, 117, 126, 138, 144, 151, 153, 157, 160]
# number of selected features: 30
# error rate on training set: 0.009094846253789535
# error rate on testing set: 0.02777777777777779

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.71
