# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.023170203551320934
# Classification error on testing sets using all features: 0.04292929292929293
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 6.0 out of 100
# corresponding indices: [28, 36, 109, 138, 144, 160]
# classification error on train sets: 0.03746210480727585
# classification error on test sets: 0.0661616161616162
# solution 1:
# number of selected features is: 29.0 out of 100
# corresponding indices: [1, 4, 5, 6, 24, 28, 30, 31, 36, 54, 65, 66, 73, 75, 77, 87, 93, 95, 99, 106, 110, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.03232323232323231
# solution 2:
# number of selected features is: 25.0 out of 100
# corresponding indices: [1, 4, 5, 24, 28, 31, 36, 54, 65, 66, 75, 87, 93, 99, 110, 116, 117, 126, 133, 138, 140, 144, 157, 160, 163]
# classification error on train sets: 0.011909917713295748
# classification error on test sets: 0.034848484848484795
# solution 3:
# number of selected features is: 5.0 out of 100
# corresponding indices: [28, 36, 138, 144, 160]
# classification error on train sets: 0.043741879601559064
# classification error on test sets: 0.07020202020202015
# solution 4:
# number of selected features is: 44.0 out of 100
# corresponding indices: [4, 5, 6, 8, 11, 21, 24, 25, 28, 30, 31, 36, 39, 49, 51, 54, 65, 66, 67, 71, 73, 75, 76, 87, 90, 93, 95, 99, 102, 106, 109, 115, 116, 117, 126, 138, 140, 141, 144, 147, 157, 160, 162, 163]
# classification error on train sets: 0.009094846253789535
# classification error on test sets: 0.02777777777777779
# solution 5:
# number of selected features is: 7.0 out of 100
# corresponding indices: [28, 36, 109, 138, 144, 153, 160]
# classification error on train sets: 0.03508012126461668
# classification error on test sets: 0.06717171717171722
# solution 6:
# number of selected features is: 30.0 out of 100
# corresponding indices: [1, 4, 5, 6, 24, 28, 30, 31, 36, 54, 65, 66, 73, 75, 87, 93, 95, 99, 106, 110, 116, 117, 126, 133, 138, 140, 144, 157, 160, 163]
# classification error on train sets: 0.009527934170636687
# classification error on test sets: 0.03181818181818186
# solution 7:
# number of selected features is: 26.0 out of 100
# corresponding indices: [1, 4, 5, 6, 11, 24, 28, 30, 31, 36, 54, 65, 75, 87, 93, 99, 106, 117, 126, 133, 138, 140, 144, 157, 160, 163]
# classification error on train sets: 0.010394110004330881
# classification error on test sets: 0.034848484848484795
# solution 8:
# number of selected features is: 11.0 out of 100
# corresponding indices: [13, 28, 31, 36, 49, 109, 116, 138, 144, 153, 160]
# classification error on train sets: 0.027717626678215646
# classification error on test sets: 0.05353535353535355
# solution 9:
# number of selected features is: 25.0 out of 100
# corresponding indices: [1, 4, 5, 6, 24, 28, 30, 31, 36, 54, 65, 75, 87, 93, 99, 106, 116, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.011909917713295748
# classification error on test sets: 0.03282828282828287
# solution 10:
# number of selected features is: 4.0 out of 100
# corresponding indices: [28, 36, 138, 160]
# classification error on train sets: 0.05045474231268943
# classification error on test sets: 0.08383838383838382
# solution 11:
# number of selected features is: 9.0 out of 100
# corresponding indices: [28, 36, 49, 54, 109, 138, 144, 153, 160]
# classification error on train sets: 0.03031615417929845
# classification error on test sets: 0.061111111111111116
# solution 12:
# number of selected features is: 20.0 out of 100
# corresponding indices: [1, 4, 5, 6, 11, 28, 30, 31, 36, 54, 75, 87, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.015591165006496266
# classification error on test sets: 0.043939393939393945
# solution 13:
# number of selected features is: 28.0 out of 100
# corresponding indices: [1, 4, 5, 6, 24, 28, 30, 31, 36, 54, 65, 67, 75, 87, 93, 99, 102, 106, 110, 116, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.01017756604590736
# classification error on test sets: 0.03232323232323231
# solution 14:
# number of selected features is: 9.0 out of 100
# corresponding indices: [28, 36, 54, 74, 109, 138, 140, 153, 160]
# classification error on train sets: 0.03031615417929845
# classification error on test sets: 0.05858585858585863
# solution 15:
# number of selected features is: 12.0 out of 100
# corresponding indices: [13, 28, 31, 36, 49, 102, 109, 116, 138, 144, 153, 160]
# classification error on train sets: 0.027501082719792125
# classification error on test sets: 0.051515151515151514
# solution 16:
# number of selected features is: 53.0 out of 100
# corresponding indices: [1, 2, 4, 5, 6, 8, 11, 18, 21, 24, 25, 28, 30, 31, 36, 39, 41, 50, 51, 54, 61, 65, 66, 71, 73, 75, 76, 77, 82, 87, 90, 93, 106, 107, 109, 114, 116, 117, 121, 122, 126, 130, 138, 141, 144, 145, 147, 152, 153, 157, 160, 162, 163]
# classification error on train sets: 0.008445214378518862
# classification error on test sets: 0.028282828282828243
# solution 17:
# number of selected features is: 16.0 out of 100
# corresponding indices: [1, 4, 11, 28, 31, 36, 54, 65, 75, 117, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.021004763967085283
# classification error on test sets: 0.051515151515151514
# solution 18:
# number of selected features is: 8.0 out of 100
# corresponding indices: [28, 36, 54, 109, 138, 144, 153, 160]
# classification error on train sets: 0.03334776959722818
# classification error on test sets: 0.06666666666666665
# solution 19:
# number of selected features is: 26.0 out of 100
# corresponding indices: [1, 4, 5, 6, 11, 24, 28, 30, 31, 36, 54, 65, 75, 87, 93, 95, 99, 106, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.010394110004330881
# classification error on test sets: 0.036363636363636376
# solution 20:
# number of selected features is: 50.0 out of 100
# corresponding indices: [1, 2, 4, 5, 6, 8, 11, 18, 21, 24, 25, 28, 30, 31, 36, 39, 41, 51, 54, 65, 66, 67, 71, 73, 75, 77, 82, 87, 90, 93, 95, 106, 107, 109, 114, 116, 117, 122, 126, 130, 138, 141, 144, 145, 147, 152, 153, 157, 160, 163]
# classification error on train sets: 0.008878302295366014
# classification error on test sets: 0.029797979797979823
# solution 21:
# number of selected features is: 23.0 out of 100
# corresponding indices: [1, 4, 5, 6, 24, 28, 30, 31, 36, 54, 67, 75, 87, 93, 99, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.012992637505413573
# classification error on test sets: 0.03383838383838389
# solution 22:
# number of selected features is: 21.0 out of 100
# corresponding indices: [1, 4, 5, 6, 11, 28, 30, 31, 36, 54, 75, 87, 93, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.014724989172802072
# classification error on test sets: 0.04292929292929293
# solution 23:
# number of selected features is: 18.0 out of 100
# corresponding indices: [1, 4, 5, 11, 28, 30, 31, 36, 54, 65, 75, 117, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.019055868341273263
# classification error on test sets: 0.04646464646464643
# solution 24:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 4, 5, 6, 28, 30, 31, 36, 54, 75, 87, 116, 117, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.017540060632308396
# classification error on test sets: 0.042424242424242475
# solution 25:
# number of selected features is: 14.0 out of 100
# corresponding indices: [1, 4, 28, 36, 54, 65, 75, 87, 117, 133, 138, 140, 144, 160]
# classification error on train sets: 0.02425292334343876
# classification error on test sets: 0.05555555555555558
# solution 26:
# number of selected features is: 10.0 out of 100
# corresponding indices: [28, 36, 54, 109, 133, 138, 140, 144, 153, 160]
# classification error on train sets: 0.029883066262451297
# classification error on test sets: 0.06212121212121213
# solution 27:
# number of selected features is: 24.0 out of 100
# corresponding indices: [1, 4, 5, 6, 24, 28, 30, 31, 36, 54, 75, 87, 93, 99, 110, 116, 117, 126, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.01212646167171938
# classification error on test sets: 0.03383838383838389
# solution 28:
# number of selected features is: 17.0 out of 100
# corresponding indices: [1, 4, 28, 31, 36, 54, 65, 75, 87, 106, 116, 117, 133, 138, 140, 144, 160]
# classification error on train sets: 0.02013858813339109
# classification error on test sets: 0.04797979797979801
# solution 29:
# number of selected features is: 18.0 out of 100
# corresponding indices: [1, 4, 5, 6, 28, 30, 36, 54, 75, 87, 99, 117, 133, 138, 140, 144, 157, 160]
# classification error on train sets: 0.019055868341273263
# classification error on test sets: 0.045454545454545414
# solution 30:
# number of selected features is: 22.0 out of 100
# corresponding indices: [1, 4, 6, 11, 24, 28, 30, 31, 36, 54, 65, 75, 87, 99, 117, 133, 138, 140, 144, 157, 160, 163]
# classification error on train sets: 0.013858813339107878
# classification error on test sets: 0.03434343434343434
# solution 31:
# number of selected features is: 55.0 out of 100
# corresponding indices: [1, 2, 4, 5, 6, 8, 11, 18, 21, 24, 25, 28, 30, 31, 36, 39, 41, 50, 51, 54, 61, 65, 66, 67, 71, 73, 75, 76, 77, 82, 87, 90, 93, 95, 106, 107, 109, 114, 116, 117, 121, 122, 126, 130, 138, 141, 144, 145, 147, 152, 153, 157, 160, 162, 163]
# classification error on train sets: 0.00801212646167171
# classification error on test sets: 0.027272727272727226
# solution 32:
# number of selected features is: 15.0 out of 100
# corresponding indices: [1, 4, 28, 31, 36, 54, 65, 75, 87, 117, 133, 138, 140, 144, 160]
# classification error on train sets: 0.022087483759203108
# classification error on test sets: 0.051515151515151514
# solution 33:
# number of selected features is: 51.0 out of 100
# corresponding indices: [1, 2, 4, 5, 6, 8, 11, 18, 21, 24, 25, 28, 30, 31, 36, 39, 41, 51, 54, 65, 66, 67, 71, 73, 75, 76, 77, 82, 87, 90, 93, 95, 106, 107, 109, 114, 116, 117, 122, 126, 130, 138, 141, 144, 145, 147, 152, 153, 157, 160, 163]
# classification error on train sets: 0.008661758336942382
# classification error on test sets: 0.030303030303030276
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [1, 2, 4, 5, 6, 8, 11, 18, 21, 24, 25, 28, 30, 31, 36, 39, 41, 50, 51, 54, 61, 65, 66, 67, 71, 73, 75, 76, 77, 82, 87, 90, 93, 95, 106, 107, 109, 114, 116, 117, 121, 122, 126, 130, 138, 141, 144, 145, 147, 152, 153, 157, 160, 162, 163]
# number of selected features: 55
# error rate on training set: 0.00801212646167171
# error rate on testing set: 0.027272727272727226

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.81
