# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.025335643135556474
# Classification error on testing sets using all features: 0.03686868686868683
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 9.0 out of 100
# corresponding indices: [4, 8, 10, 24, 41, 77, 132, 141, 162]
# classification error on train sets: 0.03746210480727585
# classification error on test sets: 0.055050505050505016
# solution 1:
# number of selected features is: 10.0 out of 100
# corresponding indices: [4, 8, 10, 24, 29, 41, 77, 132, 141, 162]
# classification error on train sets: 0.03334776959722818
# classification error on test sets: 0.05555555555555558
# solution 2:
# number of selected features is: 20.0 out of 100
# corresponding indices: [4, 8, 10, 24, 25, 28, 29, 31, 39, 40, 41, 47, 54, 77, 78, 132, 141, 157, 160, 162]
# classification error on train sets: 0.017756604590731917
# classification error on test sets: 0.036363636363636376
# solution 3:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 28, 31, 39, 40, 41, 47, 77, 78, 97, 132, 141, 160, 162]
# classification error on train sets: 0.019488956258120416
# classification error on test sets: 0.03686868686868683
# solution 4:
# number of selected features is: 36.0 out of 100
# corresponding indices: [1, 3, 4, 5, 8, 10, 12, 15, 20, 21, 24, 25, 28, 30, 31, 35, 36, 41, 44, 47, 54, 66, 67, 77, 86, 97, 117, 126, 138, 140, 143, 152, 157, 160, 162, 163]
# classification error on train sets: 0.009744478129060208
# classification error on test sets: 0.02777777777777779
# solution 5:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 28, 29, 31, 40, 41, 47, 54, 77, 78, 132, 141, 157, 162]
# classification error on train sets: 0.019488956258120416
# classification error on test sets: 0.03686868686868683
# solution 6:
# number of selected features is: 21.0 out of 100
# corresponding indices: [4, 8, 10, 24, 25, 28, 31, 35, 39, 40, 41, 47, 54, 77, 86, 97, 132, 141, 157, 160, 162]
# classification error on train sets: 0.01667388479861409
# classification error on test sets: 0.036363636363636376
# solution 7:
# number of selected features is: 8.0 out of 100
# corresponding indices: [4, 8, 10, 24, 41, 132, 141, 162]
# classification error on train sets: 0.0404937202252057
# classification error on test sets: 0.05757575757575761
# solution 8:
# number of selected features is: 6.0 out of 100
# corresponding indices: [4, 8, 10, 24, 41, 162]
# classification error on train sets: 0.0537029016890429
# classification error on test sets: 0.08585858585858586
# solution 9:
# number of selected features is: 11.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 41, 77, 97, 132, 141, 162]
# classification error on train sets: 0.031182330012992643
# classification error on test sets: 0.0505050505050505
# solution 10:
# number of selected features is: 14.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 40, 41, 77, 97, 132, 138, 141, 162]
# classification error on train sets: 0.025119099177132953
# classification error on test sets: 0.05101010101010106
# solution 11:
# number of selected features is: 7.0 out of 100
# corresponding indices: [4, 8, 10, 24, 41, 132, 162]
# classification error on train sets: 0.046123863144218236
# classification error on test sets: 0.06767676767676767
# solution 12:
# number of selected features is: 28.0 out of 100
# corresponding indices: [1, 4, 8, 10, 11, 21, 24, 25, 28, 30, 31, 35, 39, 40, 41, 47, 54, 75, 77, 78, 86, 97, 116, 132, 141, 157, 160, 162]
# classification error on train sets: 0.011476829796448706
# classification error on test sets: 0.027272727272727226
# solution 13:
# number of selected features is: 33.0 out of 100
# corresponding indices: [1, 4, 5, 8, 10, 11, 21, 24, 25, 28, 30, 31, 35, 39, 40, 41, 47, 54, 67, 75, 77, 78, 86, 97, 116, 117, 132, 141, 151, 152, 157, 160, 162]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.02323232323232327
# solution 14:
# number of selected features is: 29.0 out of 100
# corresponding indices: [1, 4, 8, 10, 11, 21, 24, 25, 28, 30, 31, 35, 39, 40, 41, 47, 54, 75, 77, 78, 86, 97, 116, 117, 132, 141, 157, 160, 162]
# classification error on train sets: 0.010394110004330881
# classification error on test sets: 0.025252525252525304
# solution 15:
# number of selected features is: 12.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 41, 77, 97, 132, 141, 162]
# classification error on train sets: 0.02858380251190995
# classification error on test sets: 0.0505050505050505
# solution 16:
# number of selected features is: 21.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 28, 31, 39, 40, 41, 47, 54, 77, 86, 97, 132, 141, 157, 160, 162]
# classification error on train sets: 0.01667388479861409
# classification error on test sets: 0.034848484848484795
# solution 17:
# number of selected features is: 23.0 out of 100
# corresponding indices: [1, 4, 8, 10, 20, 24, 25, 28, 31, 39, 40, 41, 46, 47, 77, 78, 86, 97, 132, 141, 157, 160, 162]
# classification error on train sets: 0.013858813339107878
# classification error on test sets: 0.037878787878787845
# solution 18:
# number of selected features is: 24.0 out of 100
# corresponding indices: [1, 4, 8, 10, 20, 24, 25, 28, 31, 39, 40, 41, 46, 47, 54, 77, 78, 86, 97, 132, 141, 157, 160, 162]
# classification error on train sets: 0.012559549588566532
# classification error on test sets: 0.03383838383838389
# solution 19:
# number of selected features is: 12.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 41, 77, 97, 117, 132, 141, 162]
# classification error on train sets: 0.02858380251190995
# classification error on test sets: 0.051515151515151514
# solution 20:
# number of selected features is: 27.0 out of 100
# corresponding indices: [1, 4, 8, 10, 11, 21, 24, 25, 28, 30, 31, 35, 39, 40, 41, 47, 54, 75, 77, 78, 86, 97, 132, 141, 157, 160, 162]
# classification error on train sets: 0.01212646167171938
# classification error on test sets: 0.03080808080808084
# solution 21:
# number of selected features is: 31.0 out of 100
# corresponding indices: [1, 4, 5, 8, 10, 11, 21, 24, 25, 28, 30, 31, 35, 39, 40, 41, 47, 54, 67, 75, 77, 78, 86, 97, 116, 117, 132, 141, 157, 160, 162]
# classification error on train sets: 0.01017756604590736
# classification error on test sets: 0.024242424242424288
# solution 22:
# number of selected features is: 17.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 28, 31, 40, 41, 77, 78, 97, 132, 138, 141, 162]
# classification error on train sets: 0.021870939800779587
# classification error on test sets: 0.0444444444444444
# solution 23:
# number of selected features is: 16.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 31, 40, 41, 77, 78, 97, 132, 138, 141, 162]
# classification error on train sets: 0.02252057167605026
# classification error on test sets: 0.04494949494949496
# solution 24:
# number of selected features is: 22.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 28, 31, 39, 40, 41, 46, 47, 77, 78, 86, 97, 132, 141, 157, 160, 162]
# classification error on train sets: 0.015158077089649225
# classification error on test sets: 0.039393939393939426
# solution 25:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 28, 31, 39, 40, 41, 47, 77, 78, 97, 132, 141, 157, 162]
# classification error on train sets: 0.019488956258120416
# classification error on test sets: 0.04040404040404044
# solution 26:
# number of selected features is: 18.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 31, 39, 40, 41, 77, 78, 97, 132, 141, 143, 160, 162]
# classification error on train sets: 0.02013858813339109
# classification error on test sets: 0.04595959595959598
# solution 27:
# number of selected features is: 15.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 25, 40, 41, 77, 78, 97, 132, 138, 141, 162]
# classification error on train sets: 0.023170203551320934
# classification error on test sets: 0.04595959595959598
# solution 28:
# number of selected features is: 13.0 out of 100
# corresponding indices: [1, 4, 8, 10, 24, 31, 41, 77, 97, 117, 132, 141, 162]
# classification error on train sets: 0.027284538761368604
# classification error on test sets: 0.048484848484848464
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [1, 4, 5, 8, 10, 11, 21, 24, 25, 28, 30, 31, 35, 39, 40, 41, 47, 54, 67, 75, 77, 78, 86, 97, 116, 117, 132, 141, 151, 152, 157, 160, 162]
# number of selected features: 33
# error rate on training set: 0.009961022087483729
# error rate on testing set: 0.02323232323232327

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.75
