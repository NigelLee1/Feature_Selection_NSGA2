# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.023819835426591607
# Classification error on testing sets using all features: 0.03535353535353536
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 8.0 out of 100
# corresponding indices: [18, 28, 47, 54, 102, 132, 140, 160]
# classification error on train sets: 0.03702901689042881
# classification error on test sets: 0.06262626262626259
# solution 1:
# number of selected features is: 6.0 out of 100
# corresponding indices: [18, 28, 47, 54, 132, 160]
# classification error on train sets: 0.04742312689475958
# classification error on test sets: 0.07272727272727275
# solution 2:
# number of selected features is: 5.0 out of 100
# corresponding indices: [18, 28, 47, 54, 132]
# classification error on train sets: 0.059982676483326114
# classification error on test sets: 0.08838383838383834
# solution 3:
# number of selected features is: 16.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 87, 99, 122, 132, 140, 144, 151, 160]
# classification error on train sets: 0.021870939800779587
# classification error on test sets: 0.037878787878787845
# solution 4:
# number of selected features is: 33.0 out of 100
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 31, 47, 50, 53, 54, 66, 71, 77, 87, 93, 94, 99, 109, 112, 115, 122, 129, 130, 132, 138, 140, 144, 151, 154, 158, 160]
# classification error on train sets: 0.011476829796448706
# classification error on test sets: 0.02626262626262621
# solution 5:
# number of selected features is: 14.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 87, 94, 99, 132, 140, 144, 160]
# classification error on train sets: 0.023819835426591607
# classification error on test sets: 0.04141414141414146
# solution 6:
# number of selected features is: 13.0 out of 100
# corresponding indices: [18, 28, 31, 47, 50, 54, 73, 87, 102, 132, 140, 144, 160]
# classification error on train sets: 0.0246860112602858
# classification error on test sets: 0.04191919191919191
# solution 7:
# number of selected features is: 25.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 71, 73, 87, 94, 99, 109, 112, 116, 117, 122, 132, 138, 140, 144, 151, 158, 160]
# classification error on train sets: 0.013209181463837205
# classification error on test sets: 0.03181818181818186
# solution 8:
# number of selected features is: 12.0 out of 100
# corresponding indices: [18, 28, 31, 47, 50, 54, 73, 102, 132, 140, 144, 160]
# classification error on train sets: 0.0264183629276743
# classification error on test sets: 0.05202020202020197
# solution 9:
# number of selected features is: 11.0 out of 100
# corresponding indices: [18, 28, 47, 50, 54, 73, 102, 132, 140, 144, 160]
# classification error on train sets: 0.029449978345604144
# classification error on test sets: 0.05555555555555558
# solution 10:
# number of selected features is: 40.0 out of 100
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 31, 47, 50, 53, 54, 66, 71, 73, 77, 87, 93, 94, 98, 99, 102, 109, 112, 115, 116, 117, 122, 127, 129, 130, 132, 138, 144, 151, 152, 153, 154, 158, 160]
# classification error on train sets: 0.01017756604590736
# classification error on test sets: 0.026767676767676774
# solution 11:
# number of selected features is: 23.0 out of 100
# corresponding indices: [4, 18, 21, 25, 28, 31, 39, 47, 50, 54, 66, 87, 94, 109, 115, 116, 122, 132, 140, 144, 158, 160, 166]
# classification error on train sets: 0.013858813339107878
# classification error on test sets: 0.033333333333333326
# solution 12:
# number of selected features is: 35.0 out of 100
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 31, 47, 50, 53, 54, 66, 71, 77, 87, 93, 94, 99, 109, 112, 115, 116, 122, 129, 130, 132, 138, 144, 151, 152, 153, 154, 158, 160]
# classification error on train sets: 0.010827197921178033
# classification error on test sets: 0.027272727272727226
# solution 13:
# number of selected features is: 10.0 out of 100
# corresponding indices: [18, 25, 28, 47, 54, 87, 102, 132, 140, 160]
# classification error on train sets: 0.03204850584668684
# classification error on test sets: 0.0601010101010101
# solution 14:
# number of selected features is: 41.0 out of 100
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 30, 31, 47, 50, 53, 54, 66, 71, 73, 77, 87, 93, 94, 98, 99, 102, 109, 112, 115, 116, 117, 122, 127, 129, 130, 132, 138, 144, 151, 152, 153, 154, 158, 160]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.027272727272727226
# solution 15:
# number of selected features is: 7.0 out of 100
# corresponding indices: [18, 28, 47, 54, 132, 144, 160]
# classification error on train sets: 0.04071026418362933
# classification error on test sets: 0.06414141414141417
# solution 16:
# number of selected features is: 20.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 87, 94, 99, 109, 112, 122, 132, 138, 140, 144, 151, 160]
# classification error on train sets: 0.015807708964919898
# classification error on test sets: 0.03535353535353536
# solution 17:
# number of selected features is: 29.0 out of 100
# corresponding indices: [4, 18, 25, 28, 31, 39, 47, 50, 54, 66, 67, 71, 87, 94, 99, 109, 112, 115, 116, 122, 132, 138, 140, 144, 151, 152, 158, 160, 166]
# classification error on train sets: 0.011693373754872227
# classification error on test sets: 0.029797979797979823
# solution 18:
# number of selected features is: 33.0 out of 100
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 31, 47, 50, 53, 54, 66, 77, 87, 93, 94, 99, 109, 112, 115, 116, 122, 129, 130, 132, 138, 144, 151, 153, 154, 158, 160]
# classification error on train sets: 0.011476829796448706
# classification error on test sets: 0.025757575757575757
# solution 19:
# number of selected features is: 21.0 out of 100
# corresponding indices: [4, 18, 28, 31, 39, 47, 50, 54, 66, 71, 87, 94, 109, 116, 122, 132, 138, 140, 144, 151, 160]
# classification error on train sets: 0.015374621048072745
# classification error on test sets: 0.03838383838383841
# solution 20:
# number of selected features is: 19.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 73, 87, 94, 109, 112, 122, 132, 140, 144, 151, 160]
# classification error on train sets: 0.017540060632308396
# classification error on test sets: 0.03838383838383841
# solution 21:
# number of selected features is: 33.0 out of 100
# corresponding indices: [4, 5, 18, 24, 25, 28, 31, 39, 47, 50, 54, 66, 67, 71, 87, 93, 94, 99, 109, 112, 115, 116, 122, 129, 132, 138, 140, 144, 151, 152, 153, 158, 160]
# classification error on train sets: 0.011476829796448706
# classification error on test sets: 0.030303030303030276
# solution 22:
# number of selected features is: 18.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 87, 94, 109, 112, 122, 132, 140, 144, 151, 160]
# classification error on train sets: 0.01818969250757907
# classification error on test sets: 0.03888888888888886
# solution 23:
# number of selected features is: 9.0 out of 100
# corresponding indices: [18, 25, 28, 47, 54, 102, 132, 140, 160]
# classification error on train sets: 0.033564313555651815
# classification error on test sets: 0.05606060606060603
# solution 24:
# number of selected features is: 39.0 out of 100
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 31, 47, 50, 53, 54, 66, 71, 73, 77, 87, 93, 94, 98, 99, 102, 109, 112, 115, 116, 122, 129, 130, 132, 138, 144, 151, 152, 153, 154, 158, 160, 166]
# classification error on train sets: 0.010394110004330881
# classification error on test sets: 0.02777777777777779
# solution 25:
# number of selected features is: 17.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 87, 94, 109, 122, 132, 140, 144, 151, 160]
# classification error on train sets: 0.019705500216543936
# classification error on test sets: 0.03888888888888886
# solution 26:
# number of selected features is: 19.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 87, 94, 99, 112, 122, 132, 138, 140, 144, 151, 160]
# classification error on train sets: 0.017540060632308396
# classification error on test sets: 0.034848484848484795
# solution 27:
# number of selected features is: 28.0 out of 100
# corresponding indices: [4, 5, 8, 18, 25, 28, 31, 39, 47, 50, 54, 66, 87, 99, 109, 112, 116, 122, 129, 130, 132, 138, 140, 144, 152, 153, 158, 160]
# classification error on train sets: 0.012992637505413573
# classification error on test sets: 0.02777777777777779
# solution 28:
# number of selected features is: 24.0 out of 100
# corresponding indices: [4, 18, 28, 31, 47, 50, 54, 66, 71, 73, 87, 94, 99, 109, 112, 116, 122, 132, 138, 140, 144, 151, 158, 160]
# classification error on train sets: 0.013425725422260726
# classification error on test sets: 0.033333333333333326
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [4, 5, 8, 18, 24, 25, 28, 31, 47, 50, 53, 54, 66, 77, 87, 93, 94, 99, 109, 112, 115, 116, 122, 129, 130, 132, 138, 144, 151, 153, 154, 158, 160]
# number of selected features: 33
# error rate on training set: 0.011476829796448706
# error rate on testing set: 0.025757575757575757

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.8
