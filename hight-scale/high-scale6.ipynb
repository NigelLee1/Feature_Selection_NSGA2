# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.02446946730186228
# Classification error on testing sets using all features: 0.04040404040404044
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 10.0 out of 100
# corresponding indices: [1, 4, 13, 20, 65, 71, 104, 119, 137, 138]
# classification error on train sets: 0.03291468168038114
# classification error on test sets: 0.0601010101010101
# solution 1:
# number of selected features is: 9.0 out of 100
# corresponding indices: [1, 4, 13, 20, 65, 71, 104, 119, 138]
# classification error on train sets: 0.03529666522304031
# classification error on test sets: 0.0636363636363636
# solution 2:
# number of selected features is: 11.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 36, 65, 71, 104, 119, 138]
# classification error on train sets: 0.03074924209614549
# classification error on test sets: 0.04898989898989903
# solution 3:
# number of selected features is: 8.0 out of 100
# corresponding indices: [1, 4, 13, 20, 71, 104, 119, 138]
# classification error on train sets: 0.04027717626678218
# classification error on test sets: 0.07171717171717173
# solution 4:
# number of selected features is: 12.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 36, 65, 71, 104, 119, 137, 138]
# classification error on train sets: 0.027717626678215646
# classification error on test sets: 0.05252525252525253
# solution 5:
# number of selected features is: 18.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 36, 54, 65, 71, 80, 104, 117, 119, 126, 137, 138, 141, 157]
# classification error on train sets: 0.01862278042442611
# classification error on test sets: 0.046969696969696995
# solution 6:
# number of selected features is: 16.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 36, 54, 65, 71, 104, 117, 119, 126, 137, 138, 141]
# classification error on train sets: 0.021437851883932435
# classification error on test sets: 0.04898989898989903
# solution 7:
# number of selected features is: 10.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 65, 71, 104, 119, 138]
# classification error on train sets: 0.03291468168038114
# classification error on test sets: 0.061111111111111116
# solution 8:
# number of selected features is: 15.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 36, 54, 65, 71, 104, 119, 126, 137, 138, 141]
# classification error on train sets: 0.023386747509744454
# classification error on test sets: 0.04898989898989903
# solution 9:
# number of selected features is: 15.0 out of 100
# corresponding indices: [1, 4, 13, 20, 36, 54, 65, 71, 80, 98, 104, 119, 126, 138, 141]
# classification error on train sets: 0.023386747509744454
# classification error on test sets: 0.04494949494949496
# solution 10:
# number of selected features is: 24.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 28, 30, 34, 36, 54, 65, 67, 71, 80, 95, 98, 104, 117, 119, 126, 138, 141, 160]
# classification error on train sets: 0.013425725422260726
# classification error on test sets: 0.03131313131313129
# solution 11:
# number of selected features is: 13.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 30, 36, 65, 71, 104, 119, 137, 138]
# classification error on train sets: 0.02663490688609793
# classification error on test sets: 0.0505050505050505
# solution 12:
# number of selected features is: 21.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 30, 36, 54, 65, 67, 71, 80, 95, 98, 104, 117, 119, 126, 138, 157]
# classification error on train sets: 0.01645734084019057
# classification error on test sets: 0.040909090909090895
# solution 13:
# number of selected features is: 27.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 28, 30, 36, 54, 65, 67, 71, 80, 93, 95, 98, 104, 117, 119, 126, 127, 138, 140, 141, 157, 160]
# classification error on train sets: 0.011909917713295748
# classification error on test sets: 0.03181818181818186
# solution 14:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 36, 54, 65, 67, 71, 80, 95, 104, 117, 119, 126, 137, 138, 141]
# classification error on train sets: 0.017973148549155438
# classification error on test sets: 0.042424242424242475
# solution 15:
# number of selected features is: 11.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 36, 54, 71, 104, 119, 138]
# classification error on train sets: 0.03074924209614549
# classification error on test sets: 0.05555555555555558
# solution 16:
# number of selected features is: 33.0 out of 100
# corresponding indices: [1, 4, 7, 13, 18, 20, 24, 28, 30, 31, 34, 36, 47, 54, 55, 65, 66, 67, 71, 98, 104, 116, 117, 119, 126, 127, 137, 138, 140, 141, 151, 157, 160]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.024242424242424288
# solution 17:
# number of selected features is: 22.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 30, 36, 54, 65, 71, 80, 93, 95, 98, 104, 117, 119, 126, 138, 141, 157]
# classification error on train sets: 0.01602425292334342
# classification error on test sets: 0.03535353535353536
# solution 18:
# number of selected features is: 25.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 28, 30, 36, 54, 65, 67, 71, 80, 95, 98, 104, 117, 119, 126, 127, 138, 141, 157, 160]
# classification error on train sets: 0.012776093546990053
# classification error on test sets: 0.029797979797979823
# solution 19:
# number of selected features is: 17.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 36, 54, 65, 71, 80, 104, 117, 119, 126, 137, 138, 141]
# classification error on train sets: 0.019705500216543936
# classification error on test sets: 0.04747474747474745
# solution 20:
# number of selected features is: 20.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 30, 36, 54, 65, 67, 71, 104, 117, 119, 126, 137, 138, 140, 157]
# classification error on train sets: 0.017323516673884765
# classification error on test sets: 0.04343434343434338
# solution 21:
# number of selected features is: 38.0 out of 100
# corresponding indices: [1, 4, 7, 8, 13, 18, 20, 24, 28, 30, 31, 34, 36, 47, 50, 54, 55, 61, 65, 66, 67, 71, 72, 77, 98, 104, 116, 117, 119, 126, 127, 134, 138, 140, 141, 151, 157, 160]
# classification error on train sets: 0.009311390212213055
# classification error on test sets: 0.02474747474747474
# solution 22:
# number of selected features is: 31.0 out of 100
# corresponding indices: [1, 4, 5, 13, 18, 20, 24, 28, 30, 36, 54, 65, 67, 71, 80, 93, 95, 98, 104, 117, 119, 126, 127, 134, 137, 138, 140, 141, 151, 157, 160]
# classification error on train sets: 0.010610653962754402
# classification error on test sets: 0.028282828282828243
# solution 23:
# number of selected features is: 31.0 out of 100
# corresponding indices: [1, 4, 7, 13, 18, 20, 24, 28, 30, 34, 36, 47, 54, 55, 65, 67, 71, 80, 98, 104, 117, 119, 126, 127, 137, 138, 140, 141, 151, 157, 160]
# classification error on train sets: 0.010610653962754402
# classification error on test sets: 0.026767676767676774
# solution 24:
# number of selected features is: 23.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 28, 30, 34, 36, 54, 65, 67, 71, 93, 98, 104, 117, 119, 126, 138, 141, 160]
# classification error on train sets: 0.014508445214378551
# classification error on test sets: 0.03434343434343434
# solution 25:
# number of selected features is: 28.0 out of 100
# corresponding indices: [1, 4, 13, 18, 20, 24, 28, 30, 34, 36, 54, 55, 65, 67, 71, 80, 93, 95, 98, 104, 117, 119, 126, 137, 138, 141, 157, 160]
# classification error on train sets: 0.011693373754872227
# classification error on test sets: 0.03131313131313129
# solution 26:
# number of selected features is: 14.0 out of 100
# corresponding indices: [1, 4, 13, 20, 30, 36, 65, 71, 104, 119, 126, 137, 138, 141]
# classification error on train sets: 0.02446946730186228
# classification error on test sets: 0.04747474747474745
# solution 27:
# number of selected features is: 32.0 out of 100
# corresponding indices: [1, 4, 5, 13, 18, 20, 24, 28, 30, 31, 36, 47, 54, 55, 65, 66, 67, 71, 98, 104, 116, 117, 119, 126, 127, 137, 138, 140, 141, 151, 157, 160]
# classification error on train sets: 0.010394110004330881
# classification error on test sets: 0.023737373737373724
# solution 28:
# number of selected features is: 29.0 out of 100
# corresponding indices: [1, 4, 5, 13, 18, 20, 24, 28, 30, 34, 36, 54, 65, 67, 71, 80, 93, 95, 98, 104, 117, 119, 126, 127, 137, 138, 141, 157, 160]
# classification error on train sets: 0.011260285838025075
# classification error on test sets: 0.03181818181818186
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [1, 4, 5, 13, 18, 20, 24, 28, 30, 31, 36, 47, 54, 55, 65, 66, 67, 71, 98, 104, 116, 117, 119, 126, 127, 137, 138, 140, 141, 151, 157, 160]
# number of selected features: 32
# error rate on training set: 0.010394110004330881
# error rate on testing set: 0.023737373737373724

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.72
