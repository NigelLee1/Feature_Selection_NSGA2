# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.022087483759203108
# Classification error on testing sets using all features: 0.04595959595959598
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 20.0 out of 100
# corresponding indices: [6, 11, 24, 30, 31, 50, 55, 66, 67, 80, 102, 106, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.015807708964919898
# classification error on test sets: 0.04292929292929293
# solution 1:
# number of selected features is: 16.0 out of 100
# corresponding indices: [25, 31, 50, 66, 67, 72, 93, 105, 115, 118, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.019272412299696784
# classification error on test sets: 0.0444444444444444
# solution 2:
# number of selected features is: 8.0 out of 100
# corresponding indices: [66, 67, 93, 105, 140, 152, 157, 160]
# classification error on train sets: 0.03291468168038114
# classification error on test sets: 0.055050505050505016
# solution 3:
# number of selected features is: 10.0 out of 100
# corresponding indices: [31, 66, 67, 93, 105, 115, 140, 152, 157, 160]
# classification error on train sets: 0.02836725855348632
# classification error on test sets: 0.055050505050505016
# solution 4:
# number of selected features is: 6.0 out of 100
# corresponding indices: [66, 67, 93, 140, 152, 157]
# classification error on train sets: 0.047856214811606734
# classification error on test sets: 0.07525252525252524
# solution 5:
# number of selected features is: 11.0 out of 100
# corresponding indices: [25, 31, 66, 67, 93, 105, 109, 140, 152, 157, 160]
# classification error on train sets: 0.025768731052403626
# classification error on test sets: 0.04949494949494948
# solution 6:
# number of selected features is: 22.0 out of 100
# corresponding indices: [11, 18, 24, 25, 31, 50, 55, 66, 67, 72, 80, 93, 102, 107, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.015158077089649225
# classification error on test sets: 0.03535353535353536
# solution 7:
# number of selected features is: 7.0 out of 100
# corresponding indices: [66, 67, 93, 140, 152, 157, 160]
# classification error on train sets: 0.03941100043308787
# classification error on test sets: 0.07272727272727275
# solution 8:
# number of selected features is: 27.0 out of 100
# corresponding indices: [6, 11, 18, 24, 25, 30, 31, 36, 50, 55, 66, 67, 72, 80, 93, 102, 107, 116, 118, 129, 138, 140, 144, 145, 151, 152, 157]
# classification error on train sets: 0.011909917713295748
# classification error on test sets: 0.037878787878787845
# solution 9:
# number of selected features is: 19.0 out of 100
# corresponding indices: [18, 24, 25, 31, 50, 55, 66, 67, 72, 93, 105, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.017756604590731917
# classification error on test sets: 0.04292929292929293
# solution 10:
# number of selected features is: 9.0 out of 100
# corresponding indices: [66, 67, 93, 105, 140, 151, 152, 157, 160]
# classification error on train sets: 0.030099610220874817
# classification error on test sets: 0.051515151515151514
# solution 11:
# number of selected features is: 15.0 out of 100
# corresponding indices: [25, 31, 50, 66, 67, 72, 93, 105, 118, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.021221307925508914
# classification error on test sets: 0.04191919191919191
# solution 12:
# number of selected features is: 22.0 out of 100
# corresponding indices: [6, 11, 18, 24, 25, 31, 36, 50, 55, 66, 67, 72, 80, 102, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.015158077089649225
# classification error on test sets: 0.037878787878787845
# solution 13:
# number of selected features is: 23.0 out of 100
# corresponding indices: [6, 11, 18, 24, 25, 30, 31, 50, 55, 66, 67, 72, 80, 102, 116, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.014724989172802072
# classification error on test sets: 0.03535353535353536
# solution 14:
# number of selected features is: 21.0 out of 100
# corresponding indices: [6, 8, 11, 24, 25, 31, 50, 66, 67, 72, 93, 102, 105, 116, 118, 138, 140, 143, 144, 152, 157]
# classification error on train sets: 0.015591165006496266
# classification error on test sets: 0.037878787878787845
# solution 15:
# number of selected features is: 17.0 out of 100
# corresponding indices: [18, 25, 31, 50, 66, 67, 72, 93, 105, 115, 118, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.018839324382849743
# classification error on test sets: 0.045454545454545414
# solution 16:
# number of selected features is: 31.0 out of 100
# corresponding indices: [1, 6, 8, 11, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 80, 93, 102, 107, 115, 118, 129, 138, 140, 143, 144, 151, 152, 157, 160]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.03383838383838389
# solution 17:
# number of selected features is: 12.0 out of 100
# corresponding indices: [25, 31, 50, 66, 67, 93, 105, 109, 140, 152, 157, 160]
# classification error on train sets: 0.0246860112602858
# classification error on test sets: 0.04797979797979801
# solution 18:
# number of selected features is: 40.0 out of 100
# corresponding indices: [1, 5, 6, 8, 11, 14, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 74, 80, 93, 98, 100, 102, 107, 115, 116, 117, 118, 129, 130, 138, 140, 143, 144, 145, 151, 152, 157, 160]
# classification error on train sets: 0.008445214378518862
# classification error on test sets: 0.02929292929292926
# solution 19:
# number of selected features is: 13.0 out of 100
# corresponding indices: [25, 31, 50, 55, 66, 67, 93, 105, 109, 140, 152, 157, 160]
# classification error on train sets: 0.023603291468168086
# classification error on test sets: 0.04646464646464643
# solution 20:
# number of selected features is: 26.0 out of 100
# corresponding indices: [6, 11, 18, 24, 25, 30, 31, 36, 50, 55, 66, 67, 72, 80, 93, 102, 107, 116, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.01212646167171938
# classification error on test sets: 0.037878787878787845
# solution 21:
# number of selected features is: 26.0 out of 100
# corresponding indices: [5, 6, 8, 11, 18, 24, 25, 31, 36, 50, 55, 66, 67, 72, 80, 102, 116, 118, 127, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.01212646167171938
# classification error on test sets: 0.04141414141414146
# solution 22:
# number of selected features is: 32.0 out of 100
# corresponding indices: [1, 5, 6, 8, 11, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 74, 80, 93, 102, 116, 118, 129, 138, 140, 143, 144, 151, 152, 157, 160]
# classification error on train sets: 0.009744478129060208
# classification error on test sets: 0.03383838383838389
# solution 23:
# number of selected features is: 24.0 out of 100
# corresponding indices: [11, 18, 24, 25, 31, 36, 50, 55, 66, 67, 72, 80, 93, 102, 107, 116, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.01429190125595492
# classification error on test sets: 0.03888888888888886
# solution 24:
# number of selected features is: 25.0 out of 100
# corresponding indices: [5, 6, 8, 11, 18, 24, 25, 31, 36, 50, 55, 66, 67, 72, 102, 116, 118, 127, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.012559549588566532
# classification error on test sets: 0.03888888888888886
# solution 25:
# number of selected features is: 24.0 out of 100
# corresponding indices: [6, 11, 18, 24, 25, 30, 31, 36, 50, 55, 66, 67, 72, 80, 102, 116, 118, 129, 138, 140, 144, 151, 152, 157]
# classification error on train sets: 0.01429190125595492
# classification error on test sets: 0.03535353535353536
# solution 26:
# number of selected features is: 29.0 out of 100
# corresponding indices: [6, 11, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 80, 93, 102, 107, 116, 118, 129, 138, 140, 143, 144, 145, 151, 152, 157]
# classification error on train sets: 0.011043741879601554
# classification error on test sets: 0.037878787878787845
# solution 27:
# number of selected features is: 35.0 out of 100
# corresponding indices: [1, 5, 6, 8, 11, 14, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 74, 80, 93, 102, 107, 115, 116, 118, 129, 138, 140, 143, 144, 151, 152, 157, 160]
# classification error on train sets: 0.008878302295366014
# classification error on test sets: 0.03434343434343434
# solution 28:
# number of selected features is: 36.0 out of 100
# corresponding indices: [1, 5, 6, 8, 11, 14, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 80, 93, 98, 102, 107, 116, 117, 118, 129, 138, 140, 143, 144, 145, 151, 152, 157, 160]
# classification error on train sets: 0.008661758336942382
# classification error on test sets: 0.030303030303030276
# solution 29:
# number of selected features is: 13.0 out of 100
# corresponding indices: [25, 31, 50, 55, 66, 67, 93, 109, 129, 140, 152, 157, 160]
# classification error on train sets: 0.023603291468168086
# classification error on test sets: 0.05202020202020197
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [1, 5, 6, 8, 11, 14, 18, 24, 25, 30, 31, 36, 50, 55, 58, 66, 67, 72, 74, 80, 93, 98, 100, 102, 107, 115, 116, 117, 118, 129, 130, 138, 140, 143, 144, 145, 151, 152, 157, 160]
# number of selected features: 40
# error rate on training set: 0.008445214378518862
# error rate on testing set: 0.02929292929292926

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.77
