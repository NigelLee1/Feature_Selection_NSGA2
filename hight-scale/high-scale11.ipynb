# %%
from random import randint

import numpy as np

from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import BinaryRandomSampling
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import accuracy_score # for calculating accuracy of model
import math
import matplotlib.pyplot as plt
from pymoo.operators.crossover.ux import UniformCrossover
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.indicators.hv import HV
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)

# %%
# reading csv files
data = pd.read_csv('musk.csv', sep=",")
# data = data.head(2500)

# %%
label = pd.DataFrame(data['class'])
data.drop(labels=['class','ID','molecule_name','conformation_name'], axis=1, inplace=True)
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns = data.columns)

# %%
class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=166,
                         n_obj=2,
                         n_ieq_constr=1)

    def __classification_error__(self,bitstring):
        featureNames = []
        for i in range(len(bitstring)):
            if bitstring[i] == 1:
                featureNames.append(data.columns[i])

        if len(featureNames) == 0:
            return 1
        trainx = pd.DataFrame(xtrain[featureNames])
        trainy = ytrain
        knn = KNeighborsClassifier(n_neighbors=5)
        knn.fit(trainx, trainy.values.ravel())
        predy = knn.predict(trainx)
        ac = accuracy_score(trainy, predy)
        return 1 - ac

    def __fetures_number__(self,bitstring):
        return sum(bitstring)

    def __constrain__(self,bitstring):
        return 1 - sum(bitstring)

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = [self.__fetures_number__(x[i]) for i in range(0, len(x))]
        f2 = [self.__classification_error__(x[i]) for i in range(0, len(x))]
        g1 = [self.__constrain__(x[i]) for i in range(0, len(x))]
        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1])

# %%
f_list = []
pop_list = []
x_list = []
i_f_list = []
i_pop_list = []

    
xtrain, xtest, ytrain, ytest = train_test_split(data, label, test_size=0.3, stratify=label)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain.values.ravel())
ypred = knn.predict(xtrain)
ac = accuracy_score(ytrain, ypred)
print("Classification error on training sets using all features: " + str(1 - ac))
ypred = knn.predict(xtest)
ac = accuracy_score(ytest, ypred)
print("Classification error on testing sets using all features: " + str(1 - ac))

print("###################################################################################")
problem = MyProblem()

algorithm = NSGA2(pop_size=100,
                  sampling=BinaryRandomSampling(),
                  crossover=UniformCrossover(prob=0.9),
                  mutation=BitflipMutation(prob=0.01),
                  eliminate_duplicates=True)

res = minimize(problem,
               algorithm,
               ("n_gen", 100),
               verbose=False,
               save_history=True)
i_f = res.history[0].opt.get("F")
i_pop = res.history[0].pop
f = res.F
pop = res.pop
solutions = res.X
# Out:
# Classification error on training sets using all features: 0.023819835426591607
# Classification error on testing sets using all features: 0.03989898989898988
# ###################################################################################

# %%
print("the intial pareto front is plotted as: ")
plt.scatter(i_pop.get("F")[:,0], i_pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(i_f[:,0], i_f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the initial pareto front")
plt.show()
print("the final pareto front is plotted as: ")
plt.scatter(pop.get("F")[:,0], pop.get("F")[:,1], edgecolor="blue", facecolor="none", label = "solutions")
plt.scatter(f[:,0], f[:,1], marker='*', edgecolor="red", facecolor="none", label = "optimal pareto front")
plt.xlabel('number of features')
plt.ylabel('training error')
plt.legend()
plt.title("visualization of the final pareto front")
plt.show()
# Out:
# the intial pareto front is plotted as:
# the final pareto front is plotted as:

# %%
mce_on_train_solution_tnr = []
mce_on_train_tnr = 10
mce_on_test_tnr = 10
mce_on_test_solution_ttr = []
mce_on_test_ttr = 10
mce_on_train_ttr = 10

print("evaluation of the solutions on the final pareto front")
for s in range(len(solutions)):
    solution = solutions[s]
    # print("solution " + str(s) + " with a vector " + str(np.multiply(solution, 1)) + ":")
    print("solution " + str(s) + ":")
    print("number of selected features is: " + str(f[:,0][s]) + " out of 100")
    indices = [i + 1 for i, x in enumerate(np.multiply(solution, 1)) if x == 1]
    print("corresponding indices: " + str(indices))
    print("classification error on train sets: " + str(f[:, 1][s]))
    featureNames = []
    for i in range(len(solution)):
        if solution[i] == 1:
            featureNames.append(data.columns[i])
    trainx = pd.DataFrame(xtrain[featureNames])
    testx = pd.DataFrame(xtest[featureNames])
    trainy = ytrain
    testy = ytest
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(trainx, trainy.values.ravel())
    predy = knn.predict(testx)
    ac = accuracy_score(testy, predy)
    mce = 1-ac
    if f[:, 1][s] < mce_on_train_tnr:
        mce_on_train_tnr = f[:, 1][s]
        mce_on_test_tnr = mce
        mce_on_train_solution_tnr = np.multiply(solution, 1)
    if mce < mce_on_test_ttr:
        mce_on_test_ttr = mce
        mce_on_train_ttr = f[:, 1][s]
        mce_on_test_solution_ttr = np.multiply(solution, 1)
    print("classification error on test sets: " + str(mce))
print("##################################################################################################")
# Out:
# evaluation of the solutions on the final pareto front
# solution 0:
# number of selected features is: 33.0 out of 100
# corresponding indices: [3, 4, 18, 20, 24, 25, 28, 31, 36, 37, 39, 43, 44, 47, 51, 54, 60, 67, 80, 90, 98, 100, 101, 121, 126, 138, 140, 151, 152, 153, 160, 162, 165]
# classification error on train sets: 0.011909917713295748
# classification error on test sets: 0.02777777777777779
# solution 1:
# number of selected features is: 39.0 out of 100
# corresponding indices: [3, 4, 5, 6, 7, 18, 20, 24, 28, 31, 34, 36, 37, 39, 43, 47, 50, 51, 60, 67, 84, 90, 98, 100, 101, 104, 111, 112, 117, 123, 126, 138, 140, 145, 151, 152, 153, 160, 165]
# classification error on train sets: 0.010394110004330881
# classification error on test sets: 0.02626262626262621
# solution 2:
# number of selected features is: 32.0 out of 100
# corresponding indices: [1, 3, 4, 6, 18, 20, 24, 25, 28, 31, 36, 37, 39, 43, 47, 51, 54, 80, 90, 98, 100, 101, 104, 126, 138, 140, 151, 152, 160, 162, 164, 165]
# classification error on train sets: 0.0123430056301429
# classification error on test sets: 0.024242424242424288
# solution 3:
# number of selected features is: 8.0 out of 100
# corresponding indices: [3, 4, 17, 36, 43, 56, 126, 160]
# classification error on train sets: 0.03313122563880466
# classification error on test sets: 0.0505050505050505
# solution 4:
# number of selected features is: 24.0 out of 100
# corresponding indices: [1, 3, 4, 6, 7, 8, 18, 20, 24, 28, 31, 36, 43, 47, 66, 77, 90, 117, 126, 138, 140, 152, 157, 160]
# classification error on train sets: 0.014941533131225593
# classification error on test sets: 0.034848484848484795
# solution 5:
# number of selected features is: 52.0 out of 100
# corresponding indices: [3, 4, 5, 6, 7, 8, 11, 14, 18, 20, 24, 25, 28, 31, 34, 36, 37, 39, 43, 47, 50, 51, 54, 60, 67, 72, 75, 78, 80, 84, 90, 93, 98, 100, 101, 104, 111, 112, 117, 123, 126, 132, 138, 140, 143, 145, 151, 152, 153, 157, 160, 165]
# classification error on train sets: 0.008661758336942382
# classification error on test sets: 0.022222222222222254
# solution 6:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 100, 126, 140, 145, 152, 157, 160]
# classification error on train sets: 0.01645734084019057
# classification error on test sets: 0.03535353535353536
# solution 7:
# number of selected features is: 6.0 out of 100
# corresponding indices: [3, 4, 17, 36, 43, 160]
# classification error on train sets: 0.04027717626678218
# classification error on test sets: 0.058080808080808066
# solution 8:
# number of selected features is: 17.0 out of 100
# corresponding indices: [1, 3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 100, 126, 140, 152, 160]
# classification error on train sets: 0.018839324382849743
# classification error on test sets: 0.03232323232323231
# solution 9:
# number of selected features is: 12.0 out of 100
# corresponding indices: [3, 4, 18, 36, 43, 54, 77, 126, 140, 145, 152, 160]
# classification error on train sets: 0.025985275010827147
# classification error on test sets: 0.04494949494949496
# solution 10:
# number of selected features is: 5.0 out of 100
# corresponding indices: [3, 4, 36, 43, 160]
# classification error on train sets: 0.044174967518406216
# classification error on test sets: 0.0636363636363636
# solution 11:
# number of selected features is: 17.0 out of 100
# corresponding indices: [3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 100, 126, 140, 152, 157, 160]
# classification error on train sets: 0.018839324382849743
# classification error on test sets: 0.03434343434343434
# solution 12:
# number of selected features is: 25.0 out of 100
# corresponding indices: [1, 3, 4, 6, 7, 8, 18, 20, 24, 28, 31, 36, 43, 47, 66, 77, 90, 117, 126, 138, 140, 151, 152, 157, 160]
# classification error on train sets: 0.014075357297531399
# classification error on test sets: 0.03131313131313129
# solution 13:
# number of selected features is: 17.0 out of 100
# corresponding indices: [3, 4, 7, 18, 20, 28, 36, 43, 47, 54, 77, 90, 126, 140, 145, 152, 160]
# classification error on train sets: 0.018839324382849743
# classification error on test sets: 0.02777777777777779
# solution 14:
# number of selected features is: 15.0 out of 100
# corresponding indices: [3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 126, 140, 152, 160]
# classification error on train sets: 0.021221307925508914
# classification error on test sets: 0.037878787878787845
# solution 15:
# number of selected features is: 16.0 out of 100
# corresponding indices: [3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 126, 140, 145, 152, 160]
# classification error on train sets: 0.019922044174967568
# classification error on test sets: 0.03686868686868683
# solution 16:
# number of selected features is: 37.0 out of 100
# corresponding indices: [1, 3, 4, 5, 6, 8, 14, 18, 20, 24, 28, 31, 36, 39, 43, 47, 51, 73, 90, 98, 100, 101, 111, 112, 117, 123, 126, 138, 140, 143, 151, 152, 157, 160, 163, 164, 165]
# classification error on train sets: 0.010827197921178033
# classification error on test sets: 0.025252525252525304
# solution 17:
# number of selected features is: 34.0 out of 100
# corresponding indices: [1, 3, 4, 5, 6, 18, 20, 24, 25, 28, 31, 36, 37, 39, 43, 47, 50, 51, 90, 98, 100, 101, 104, 111, 112, 126, 138, 140, 151, 152, 157, 160, 164, 165]
# classification error on train sets: 0.011260285838025075
# classification error on test sets: 0.027272727272727226
# solution 18:
# number of selected features is: 19.0 out of 100
# corresponding indices: [1, 3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 80, 90, 100, 126, 140, 145, 152, 160]
# classification error on train sets: 0.01645734084019057
# classification error on test sets: 0.03282828282828287
# solution 19:
# number of selected features is: 16.0 out of 100
# corresponding indices: [3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 100, 126, 140, 152, 160]
# classification error on train sets: 0.019922044174967568
# classification error on test sets: 0.03080808080808084
# solution 20:
# number of selected features is: 26.0 out of 100
# corresponding indices: [1, 3, 4, 6, 7, 8, 18, 20, 24, 28, 31, 36, 43, 47, 66, 77, 90, 100, 111, 117, 126, 138, 140, 152, 157, 160]
# classification error on train sets: 0.013425725422260726
# classification error on test sets: 0.03282828282828287
# solution 21:
# number of selected features is: 44.0 out of 100
# corresponding indices: [3, 4, 5, 7, 18, 20, 24, 28, 31, 34, 36, 37, 39, 43, 47, 50, 51, 54, 60, 66, 67, 72, 73, 75, 84, 90, 98, 100, 101, 111, 112, 117, 123, 126, 138, 140, 151, 152, 153, 157, 160, 162, 163, 165]
# classification error on train sets: 0.009311390212213055
# classification error on test sets: 0.022727272727272707
# solution 22:
# number of selected features is: 13.0 out of 100
# corresponding indices: [1, 3, 4, 18, 36, 43, 54, 77, 90, 126, 140, 152, 160]
# classification error on train sets: 0.0246860112602858
# classification error on test sets: 0.03989898989898988
# solution 23:
# number of selected features is: 7.0 out of 100
# corresponding indices: [3, 4, 18, 36, 43, 126, 160]
# classification error on train sets: 0.035729753139887355
# classification error on test sets: 0.05555555555555558
# solution 24:
# number of selected features is: 18.0 out of 100
# corresponding indices: [3, 4, 17, 18, 28, 36, 43, 47, 54, 77, 90, 100, 126, 138, 140, 145, 152, 160]
# classification error on train sets: 0.016890428757037723
# classification error on test sets: 0.02777777777777779
# solution 25:
# number of selected features is: 14.0 out of 100
# corresponding indices: [3, 4, 18, 20, 28, 36, 43, 47, 54, 77, 90, 126, 140, 160]
# classification error on train sets: 0.022087483759203108
# classification error on test sets: 0.04292929292929293
# solution 26:
# number of selected features is: 27.0 out of 100
# corresponding indices: [1, 3, 4, 6, 7, 8, 18, 20, 24, 28, 31, 36, 43, 47, 66, 72, 77, 90, 100, 117, 126, 138, 140, 151, 152, 157, 160]
# classification error on train sets: 0.012776093546990053
# classification error on test sets: 0.02929292929292926
# solution 27:
# number of selected features is: 40.0 out of 100
# corresponding indices: [1, 3, 4, 5, 6, 7, 8, 18, 20, 24, 28, 31, 34, 36, 37, 39, 43, 47, 50, 51, 66, 67, 84, 90, 98, 100, 101, 104, 111, 112, 117, 126, 138, 140, 151, 152, 153, 160, 164, 165]
# classification error on train sets: 0.009961022087483729
# classification error on test sets: 0.022222222222222254
# solution 28:
# number of selected features is: 9.0 out of 100
# corresponding indices: [3, 4, 18, 36, 43, 77, 126, 140, 160]
# classification error on train sets: 0.02858380251190995
# classification error on test sets: 0.05353535353535355
# solution 29:
# number of selected features is: 28.0 out of 100
# corresponding indices: [1, 3, 4, 6, 7, 18, 20, 24, 28, 31, 36, 39, 43, 47, 50, 51, 80, 90, 98, 117, 126, 138, 140, 151, 152, 157, 160, 164]
# classification error on train sets: 0.012559549588566532
# classification error on test sets: 0.03181818181818186
# solution 30:
# number of selected features is: 10.0 out of 100
# corresponding indices: [3, 4, 18, 36, 43, 90, 100, 126, 140, 160]
# classification error on train sets: 0.027284538761368604
# classification error on test sets: 0.048484848484848464
# ##################################################################################################

# %%
# print("details of best solution (with minimum classification error) on traning set: ")
# indices = [i + 1 for i, x in enumerate(mce_on_train_solution_tnr) if x == 1]
# print("corresponding indices: " + 
#       str(indices))
# print("number of selected features: " + str(sum(mce_on_train_solution_tnr)))
# print("error rate on training set: " + str(mce_on_train_tnr))
# print("error rate on testing set: " + str(mce_on_test_tnr))

# %%
print("details of best solution (with minimum classification error) on testing set: ")
indices = [i + 1 for i, x in enumerate(mce_on_test_solution_ttr) if x == 1]
print("corresponding indices: " + 
      str(indices))
print("number of selected features: " + str(sum(mce_on_test_solution_ttr)))
print("error rate on training set: " + str(mce_on_train_ttr))
print("error rate on testing set: " + str(mce_on_test_ttr))
# Out:
# details of best solution (with minimum classification error) on testing set:
# corresponding indices: [3, 4, 5, 6, 7, 8, 11, 14, 18, 20, 24, 25, 28, 31, 34, 36, 37, 39, 43, 47, 50, 51, 54, 60, 67, 72, 75, 78, 80, 84, 90, 93, 98, 100, 101, 104, 111, 112, 117, 123, 126, 132, 138, 140, 143, 145, 151, 152, 153, 157, 160, 165]
# number of selected features: 52
# error rate on training set: 0.008661758336942382
# error rate on testing set: 0.022222222222222254

# %%
ref_point = np.array([1, 1])
ind = HV(ref_point=ref_point)
scaler = MinMaxScaler()
f = scaler.fit_transform(f)
hv = ind(f)
print("HV of the best pareto front:" + str(round(hv, 2)))
# Out:
# HV of the best pareto front:0.78
